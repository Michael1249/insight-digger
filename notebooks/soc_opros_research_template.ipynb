# %%
# Import required libraries
import sys
sys.path.append('../src')

# Reload the module to get updated version without logging
import importlib
if 'soc_opros_loader' in sys.modules:
    importlib.reload(sys.modules['soc_opros_loader'])

from soc_opros_loader import SocOprosLoader
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the data with informative output
loader = SocOprosLoader()
print(f"Loading data from Google Sheets...")
print(f"Sheet ID: {loader.sheet_id}")

# Load the raw data first
raw_data = loader.load_data()
print(f"Raw data loaded successfully: {raw_data.shape}")

# Parse structure to get metadata
structure_info = loader.parse_structure()
print(f"Structure parsed:")
print(f"  - {structure_info['total_statements']} statements")
print(f"  - {structure_info['total_respondents']} respondents") 

# Get the clean responses matrix
responses = loader.get_responses_matrix()
statements = loader.get_statements()
respondents = loader.get_respondents()

# Check for missing values info
nan_count = responses.isnull().sum().sum()
if nan_count > 0:
    print(f"Filled {nan_count} missing values with neutral response (3.0)")

print(f"\nData loading complete.")
print(f"  - Responses matrix shape: {responses.shape}")
print(f"  - Column names: {list(raw_data.columns)}")
print(f"  - Data range: {responses.min().min():.1f} to {responses.max().max():.1f}")
# Out:
# Loading data from Google Sheets...
# Sheet ID: 17oJL-hVMqOehHFugKHDJBmGtbWkp7e1y4ccJFnxwapk
# Raw data loaded successfully: (265, 16)
# Structure parsed:
#   - 265 statements
#   - 15 respondents
#
# Data loading complete.
#   - Responses matrix shape: (265, 15)
#   - Column names: ['statements', 'Амелия', 'Итанио', 'Отец', 'Ваал', 'Пик', 'Стилшейд', 'ПИПИПИ', 'Айса', 'Кель', 'Иезекиль', 'Нелот', 'Иннеад', 'Джазар', 'Кая', 'Айша']
#   - Data range: 1.0 to 5.0
